# %%
from math import sqrt

# %%
inpVal = int(input("Enter a number to find the square root: "))

result = sqrt(inpVal)

print("The square root of", inpVal, "is", result)
# Out:
# The square root of 56 is 7.483314773547883
