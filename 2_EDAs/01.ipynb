# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../datasets\coaster_db.csv')

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df.tail()
# Out:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1082            NaN                                 Steel
# ...

# %%
df.sample(5)
# Out:
#                            coaster_name                Length  \
# 349            The Comet (Great Escape)    4,197 ft (1,279 m)
# 758         Fahrenheit (roller coaster)      2,700 ft (820 m)
# 1047                        Candymonium    4,636 ft (1,413 m)
# 397                           Megafobia      2,956 ft (901 m)
# 188   Looping Star (Nagashima Spa Land)  1,942.3 ft (592.0 m)
#
#                   Speed            Location     Status  \
# 349    55 mph (89 km/h)        Great Escape  Operating
# 758    58 mph (93 km/h)         Hersheypark  Operating
# 1047  76 mph (122 km/h)         Hersheypark  Operating
# 397    48 mph (77 km/h)  Oakwood Theme Park  Operating
# 188    40 mph (64 km/h)  Nagashima Spa Land  Operating
#
#                                            Opening date   Type  \
# 349   1948 (Crystal Beach), June 25, 1994 (relocatio...   Wood
# 758                                        May 24, 2008  Steel
# 1047                                       July 3, 2020  Steel
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
print(df.isna().sum())
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
df.describe(include='all')
# Out:
#             coaster_name          Length             Speed Location  \
# count               1087             953               937     1087
# unique               990             569               243      280
# top     Batman: The Ride  935 ft (285 m)  50 mph (80 km/h)    Other
# freq                   7              21                63      250
# mean                 NaN             NaN               NaN      NaN
# std                  NaN             NaN               NaN      NaN
# min                  NaN             NaN               NaN      NaN
# 25%                  NaN             NaN               NaN      NaN
# 50%                  NaN             NaN               NaN      NaN
# 75%                  NaN             NaN               NaN      NaN
# max                  NaN             NaN               NaN      NaN
#
#            Status Opening date   Type Manufacturer Height restriction   Model  \
# ...

# %%
df.select_dtypes(include='number').corr()
# Out:
#                   Inversions  year_introduced  latitude  longitude  \
# Inversions          1.000000         0.211003 -0.009815   0.061589
# year_introduced     0.211003         1.000000 -0.070982   0.175913
# latitude           -0.009815        -0.070982  1.000000  -0.298488
# longitude           0.061589         0.175913 -0.298488   1.000000
# speed1_value        0.163419         0.210191 -0.121847   0.301179
# speed_mph           0.252209         0.204853 -0.063757   0.051063
# height_value        0.094811         0.087687 -0.004265  -0.092764
# height_ft           0.171330         0.232150  0.011492   0.159733
# Inversions_clean    1.000000         0.228758 -0.014043   0.087160
# Gforce_clean        0.356865        -0.066657  0.042871   0.016485
#
#                   speed1_value  speed_mph  height_value  height_ft  \
# Inversions            0.163419   0.252209      0.094811   0.171330
# year_introduced       0.210191   0.204853      0.087687   0.232150
# ...

# %%
# pd.set_option('display.max_columns', 30)
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
numeric_cols = df.select_dtypes(include=['number'])
sns.heatmap(numeric_cols.corr(), annot=True, cmap='mako')
plt.show()

# %%
df['Speed'].hist(bins=20, color='skyblue', edgecolor='black')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x='Height', y='Speed')
# Out:
# <Axes: xlabel='Height', ylabel='Speed'>

# %%
df.memory_usage()
# Out:
# Index                             132
# coaster_name                     8696
# Length                           8696
# Speed                            8696
# Location                         8696
# Status                           8696
# Opening date                     8696
# Type                             8696
# Manufacturer                     8696
# Height restriction               8696
# Model                            8696
# Height                           8696
# Inversions                       8696
# Lift/launch system               8696
# Cost                             8696
# Trains                           8696
# Park section                     8696
# Duration                         8696
# Capacity                         8696
# G-force                          8696
# Designer                         8696
# Max vertical angle               8696
# Drop                             8696
# Soft opening date                8696
# Fast Lane available              8696
# ...

# %%
df.memory_usage().sum()   # in bytes
# Out:
# np.int64(487108)

# %%
df['Speed'].value_counts()
# Out:
# Speed
# 50 mph (80 km/h)         63
# 55 mph (89 km/h)         39
# 40 mph (64 km/h)         39
# 45 mph (72 km/h)         31
# 35 mph (56 km/h)         31
#                          ..
# 121 km/h (75 mph)         1
# 91 mph (146 km/h)         1
# 70.2 mph (113.0 km/h)     1
# 49 mph (79 km/h)          1
# 80.0 km/h (49.7 mph)      1
# Name: count, Length: 243, dtype: int64

# %% [markdown]
# **scatter plot using pandas**

# %%
df.plot(kind='scatter', x='speed_mph', y='height_ft', title='Speed vs Height scatter graph')
plt.show()

# %% [markdown]
# **scatter plot using seaborn**

# %%
sns.scatterplot(data=df, x='speed_mph', y='height_ft')
# Out:
# <Axes: xlabel='speed_mph', ylabel='height_ft'>
